# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
tqdm.pandas()
import tensorflow as tf
from tensorflow.keras.layers import Embedding
import gcsfs
from google.cloud import bigquery
client = bigquery.Client()

# %%
# Get the vocab list
tags_path = "gs://edc-dev/kubeflowpipelines-default/tfx_pipeline_output/node2vec_sports_syn_0_1_0/Transform/transform_graph/18561/transform_fn/assets/node_vocab_txt"
fs = gcsfs.GCSFileSystem(project="res-nbcupea-dev-ds-sandbox-001")

with fs.open(tags_path, "r") as fid:
    tags_list = fid.read().split("\n")
tags_list = [tag for tag in tags_list if tag != ""]
tags_list
# Out:
# ['News',
#  'TV',
#  'Sports',
#  'Talk',
#  'covid-19',
#  'new',
#  'Entertainment',
#  'Football',
#  'Business & Finance',
#  'coronavirus',
#  'reports',
#  '022ae9a1-d2ac-3238-b686-96c2a5ce26ba',
#  'president',
#  'news',
#  'discuss',
#  'trump',
#  'joins',
#  'today',
#  'SportingEvent',
#  'Comedy',
#  'first',
#  'mike',
#  'show',
#  'Subgenre:Talk',
#  'Reality',
#  'one',
#  'us',
#  'c04236ee-ca40-3a75-a008-230eaa805ba4',
#  '39337ec8-062e-32ba-afc3-541adf683fce',
#  'pandemic',
#  'chris',
#  'says',
#  'nbc',
#  'joe',
#  'former',
#  'cnbcs',
#  'florio',
#  '235b584f-ef32-38fe-8c51-e769f320257f',
#  'day',
#  'nbcs',
#  'biden',
#  '2020',
#  'ddca41be-7eff-3441-96df-14b01bb41629',
#  'world',
#  'people',
#  'watch',
#  'talks',
#  'get',
#  'back',
#  '2c1b4ec5-a425-32ed-a230-26638587fbec',
#  'Soccer',
#  'house',
#  'ed68bf9f-dd4f-34b0-805f-142f3483c997',
#  'season',
#  'time',
#  'look',
#  'two',
#  '38cfc6e9-47ba-33e0-a857-143193c2b7d6',
#  'Drama',
#  'c909dfb4-1532-3d0c-a532-0a5b3798efec',
#  '700e1a8a-dcdd-3bea-a86b-7a03a595f26a',
#  'a63d70f5-4640-348c-acc2-7b5c02ea5a65',
#  '93580bfc-5c5d-3ed0-bdaf-ea8856319fde',
#  'like',
#  'ac770a39-b0c5-390f-aadd-b0f47fba1150',
#  'df07ed92-eeb7-364c-88c2-781f208be2ef',
#  '0ece18fe-c1f2-376a-b3d2-752b3c3c3a79',
#  'home',
#  'c233ee8b-fa85-376e-af7e-8973bf0a539f',
#  'd1ff0ccc-6aa3-3d47-b457-d0bb50f20d88',
#  'simms',
#  'take',
#  '58b539a5-836b-3a24-ab96-5610c185d161',
#  'could',
#  'national',
#  'make',
#  'kelly',
#  'Movies',
#  'team',
#  '28cf93d2-c1ab-345d-af9b-5f31a2d93121',
#  'york',
#  'week',
#  'said',
#  'also',
#  'ffc1c911-2f08-3db5-9055-e609996c8534',
#  'including',
#  'nfl',
#  'cabee4f0-a4be-3294-8bb9-4e0cc61ee46e',
#  'help',
#  'shares',
#  'dr',
#  'latest',
#  '10eecb3c-a753-3be9-8848-093b748818d6',
#  '510c23a2-ad1c-3a69-b3af-51a8694fdbd4',
#  'd25c50c9-3e19-3a75-b29d-827d72b2c83b',
#  '2c1fb03f-9d3e-3b71-bf75-6eb5cf631748',
#  '44a2b12a-1643-36b0-a9b7-f671cb18c0a2',
#  'c0d1daa8-79ae-38ba-91c8-3225d3c4eea3',
#  '866e3391-95ea-3b2e-a95f-1043bc588a21',
#  'white',
#  'states',
#  'discusses',
#  '590b0e0f-d5ab-314e-bc72-6bd97e4e0b6d',
#  '162f68d8-e9ff-3f51-a888-016cc50f95aa',
#  '6c1de88c-58b6-3800-9d6e-9b4b63a477f7',
#  '9df1fec1-d2ba-3844-a83e-59f3abbc5042',
#  'talk',
#  '8f831bfd-a930-3b92-8151-9d01d822f09c',
#  'family',
#  'video',
#  '06793fcd-764d-3bef-aa26-5091f8148c75',
#  'years',
#  'state',
#  'election',
#  'star',
#  '97af15e7-53fa-3d44-b0df-adabd2049e8e',
#  'michael',
#  '7d3a1b49-6b7f-362d-b0b6-b6392f284b9c',
#  '5ddff720-304f-3533-bfbe-45141b78679b',
#  'life',
#  '235b4808-4b44-3098-a7a2-78fe3ecbb25b',
#  '0bd9abd0-7dbc-33fc-be89-82c3672f3a36',
#  'c9e6e6ea-13f9-33b3-8c9a-8074b73f8cad',
#  '33b84ce0-d776-336c-b3d0-475aef0b782f',
#  'country',
#  'best',
#  '9bb723ec-b6a3-39b0-9867-ef33f78752e3',
#  'win',
#  'eae43c81-b828-3c01-8493-7213a0f1c8da',
#  'Sports non-event',
#  'john',
#  '3dfdfa1d-88b5-3c6a-8b28-b3b894e25ce4',
#  'series',
#  '7f4ad3dd-0d20-3d1b-87e7-2e395a40fafd',
#  'takes',
#  'tells',
#  'ac5ddc5a-3ee7-3819-a79e-3e27a3b91445',
#  '3401470f-2efd-3af6-b658-fc80922fb8f2',
#  'part',
#  'live',
#  'see',
#  '6f8d7f6d-60a5-3b61-9bcf-3f579e6248df',
#  'big',
#  '4ae83fd9-e4a2-32c3-b298-05d8440f3c55',
#  'league',
#  'caad458e-58a3-3490-82b6-3632c339530a',
#  'city',
#  'game',
#  'cc620d33-a803-36ae-a6c2-4f361e517486',
#  '5500c7f3-1de7-3503-8bc0-beb7265b0b37',
#  '470eb3ad-aa4a-335b-ae39-cea87dcf1c4f',
#  'year',
#  'health',
#  'f01b3aaf-806d-3acc-8b39-2071d828085b',
#  'around',
#  '630cc115-4198-3067-8201-31337316a32e',
#  '4da583b7-579f-31ce-8fc9-ed75d2642f7b',
#  'donald',
#  'd30d87bd-a624-3516-8c2b-fcd4b6a704dc',
#  'night',
#  'would',
#  '458a4a5b-849d-3633-a7d0-e9137845f96c',
#  'Special',
#  '5f4852c8-071e-3e91-b942-a0904e47b479',
#  'vaccine',
#  'trumps',
#  'may',
#  '74004ab2-c440-3971-9d0b-3b46ef77e514',
#  '989070eb-9b9b-39bb-b640-1f243cac2c4d',
#  'smith',
#  'face',
#  'host',
#  'across',
#  'last',
#  '2d22d5ca-435c-3a1a-ba86-ad4014351433',
#  '402dabad-1248-35cf-bafa-b732c728134e',
#  'correspondent',
#  'c7c59fdc-bedd-3e3c-b603-85558a7bf9d6',
#  'way',
#  '4660a438-80fe-3340-8905-36050c9fcd39',
#  'police',
#  '8ebbd7af-2a55-3d8a-96a1-c65fd3cfe593',
#  'jimmy',
#  'a80824e7-b8ec-351a-9ed2-ff99f2c783e8',
#  '4310fe7d-4553-39fd-a422-5dc5bc7d3c5d',
#  'top',
#  'black',
#  'explains',
#  'go',
#  'many',
#  '7232cd5c-3a40-33f1-93ed-355e94ef50ad',
#  'd680266a-7783-3422-824d-49bf189edb37',
#  '9a3b1e7f-1773-3d22-9197-692c1b72d0c9',
#  '6690d972-d0c8-3fa0-b0a2-b9108765aaf4',
#  'money',
#  '7b6877fb-2533-3a36-8cac-453496ed895b',
#  'squawk',
#  'man',
#  'b3993822-b432-3b00-8889-0193e9676805',
#  'e40932bf-a931-3b51-aa02-f02acc8b50a0',
#  'three',
#  '35d1e500-40f2-39b5-aa82-b8bed11c7c12',
#  'Action & Adventure',
#  '3ebb6f8c-fcd4-3220-9e46-e9ecf157fb4b',
#  'made',
#  'american',
#  '15e608b1-d6ec-32e4-844a-88534936a989',
#  'hes',
#  'ceo',
#  'f979ba6b-79b5-3a1c-a2f5-71355c1c0366',
#  'a70041ab-c01b-3d3d-982d-2231020c3e06',
#  'love',
#  'eee0c2f1-f255-31b5-92de-74ed3feae755',
#  '93f7138e-9f86-3bea-833d-fdf153f46d5c',
#  'work',
#  'ms',
#  '162c1888-42b3-3f6e-8f73-52923ce76343',
#  '18160096-f027-3037-ba5b-9fcca6d807d5',
#  'b38c1512-72bc-398f-bb39-38c3e0c10069',
#  '77bdba04-0df9-367b-b997-338c390f21c4',
#  'going',
#  '07f5faa3-7d86-3a0f-a632-f4a6775cb116',
#  'bbcf0ed3-77c6-31e6-8ee1-eff1ff9c45aa',
#  '60e8246f-2131-36c2-b233-aaf3440d05a0',
#  '8c60159d-731a-3014-b8d8-ecd50d00839b',
#  '1df4e4cf-7617-3117-9e2a-62ffbf833d5c',
#  'death',
#  'still',
#  'next',
#  '895e6ab5-9a6f-33ec-9d56-f59e550e759f',
#  'Documentary',
#  'fae0310e-8863-319f-bdec-730431d1ac4f',
#  'weekend',
#  'king',
#  '5a037839-f131-3262-aca4-d329ec85a50f',
#  'united',
#  'peter',
#  'share',
#  '47dc0058-3c54-3979-8215-21a92457bb78',
#  'tom',
#  'cases',
#  'f3a93386-ca56-3b0b-a2d4-203828a032a8',
#  'americans',
#  'biggest',
#  'find',
#  '02a54630-d262-383b-8a80-56a7900990a6',
#  'social',
#  'second',
#  'cd35b0c1-7151-31fe-90b2-b9ec67c77f53',
#  'special',
#  'a7f625e7-d86c-3ab3-8e12-8c5f283110be',
#  '3e8140b9-bd51-3b77-9166-e170b3b62f2c',
#  '97c8cf6d-da84-3b1f-8ea7-d44def46180c',
#  'bill',
#  '143cd080-ac4d-39e3-be25-16c6c25fe182',
#  'premier',
#  'a3f4a4f6-1db7-3bcd-9fe3-e152108d875b',
#  'ae7fd629-7924-313b-810c-2eff522ca633',
#  'Pro Wrestling',
#  'b2c9f217-e5a5-33e7-b9c9-1f4d245e2867',
#  '15d624a3-37cb-34eb-80f5-3ceef1d27f79',
#  'daily',
#  '2021',
#  '40929909-21fc-3c3b-8256-7f9d775f51cc',
#  'cbdb71a5-09c9-3c8d-b018-32ed510487e9',
#  'b1c9838a-41eb-3c52-a6b1-bec784db5ed5',
#  '9f641dbc-e75b-3883-90ff-e0235d3a6f68',
#  'ae6e07bd-2749-3cd1-bb5f-f55b97ead920',
#  'days',
#  'another',
#  'even',
#  'c0aa166b-9ced-3fc7-a869-044fca9e68f8',
#  '72e2ff59-8954-30a6-bf08-a4874a60dea6',
#  '434fb351-b35a-342a-a1b6-40f184c2c7af',
#  '327d6f94-5c39-35e6-b48b-77b65293c7cd',
#  'todays',
#  'Crime',
#  'shows',
#  'set',
#  'group',
#  '97684d8a-415c-3f94-afb7-b20b12ab8ffb',
#  'george',
#  '6e6d5aa0-0833-3b88-a96f-60c33e5344d5',
#  'jim',
#  'things',
#  '971403fd-b83f-3ecd-8c9b-c1f3f7c59bcf',
#  '79a43714-4392-3f7a-99a1-50e549b685b3',
#  'sports',
#  'f5291ac3-b4e2-3b2f-a1c4-509f22d1531f',
#  '7f01fa01-5ef3-35f6-a7d5-f386b42244d2',
#  'fd448dbc-b44d-34d1-8802-fae417358cf1',
#  'breaking',
#  'friends',
#  'stars',
#  'c623061f-450b-34ae-b7e7-ecc09b431c3d',
#  'say',
#  '03bfe521-21ae-312b-8c5b-e7508c030daa',
#  'young',
#  'd4687c56-dc1f-3934-a4e0-f730a6df92da',
#  'e943013b-b325-375b-acf9-3005b5813765',
#  'Mystery',
#  'Ice Hockey',
#  '5421702e-74c2-3e1e-a920-737cbdaebad3',
#  'dc5e5fdb-c563-31fb-8529-761362063a7e',
#  '09c08db1-b634-354e-90fe-0da9257563cd',
#  'plan',
#  'b613ae47-eb4e-3b1e-a814-acc52db0ba26',
#  'working',
#  '2d7ced08-b555-322d-97c0-37539103a447',
#  'making',
#  'd0b6f539-944d-3b31-9724-043dde9c873d',
#  'gets',
#  'washington',
#  'report',
#  'dd7a73ca-2e68-3c97-9c65-460e44aa6690',
#  'getting',
#  'need',
#  'd1476ba2-3343-3ac2-8d85-6e4fc943cd78',
#  'details',
#  'a4969fb2-ac47-3e1c-b5df-2896d4b2e841',
#  'Kids',
#  'looks',
#  '0d6f8a6d-f637-3e42-b712-6bb56a176018',
#  'questions',
#  'public',
#  'morning',
#  '0db259bf-f83b-39bd-96b4-7295cd7b0c43',
#  'texas',
#  'Game Show & Contest',
#  'since',
#  'join',
#  'history',
#  'eedf7c76-033d-3ebe-a355-8b479900e9f0',
#  'company',
#  'Discovery',
#  '8215c5ad-a6a4-3bf2-ba1c-0282ef494e56',
#  '95407aa9-7336-3bae-ad8c-19e6cca140d2',
#  'school',
#  '3f690a37-32bd-350b-a8a2-078faae82b68',
#  'whether',
#  'story',
#  'called',
#  'business',
#  'c7c7c3fb-d332-3bd0-ba15-54e601e8e654',
#  'Basketball',
#  '030490fb-64f2-3efe-9707-8fbbe65c6607',
#  'clarkson',
#  '7eb8b5c9-ed89-37ee-8b15-8b64a8f44e7b',
#  'box',
#  'final',
#  '798755c1-487d-3359-8804-8f9cd7a3149d',
#  '6958f373-56de-3718-bbf6-9d6367544624',
#  'interview',
#  'past',
#  '59636ceb-17b1-3f58-a246-309a3df58754',
#  'fac7295f-eae2-3d39-8ebd-9b60377a6ba4',
#  'reveals',
#  'b33e76a9-36d9-3aff-b54f-8b09958e08dc',
#  '2999cc99-63ba-35e9-a851-80e4bbf44ddf',
#  'senate',
#  'action',
#  'million',
#  'james',
#  'weeks',
#  'fans',
#  'rich',
#  '42b93762-49fa-33ae-90ee-54f7a23cb9eb',
#  'woman',
#  '6834f1d9-5a7e-3329-bbf5-f558b8335565',
#  '5c4a632c-a8eb-388a-9d50-0dc5f7a9120f',
#  'a2e144c1-41e3-3216-9df9-f26147c45239',
#  'cup',
#  'Golf',
#  'teens (ages 13-14)',
#  '524596b9-19c1-3e48-9bef-8f4a0a64145b',
#  'Thriller',
#  '4dc41d2c-81ac-380f-bae0-5bad7c7cd51d',
#  '10a11059-a39b-38f9-b230-5823dd1234ea',
#  'interviews',
#  'power',
#  'steve',
#  '6f9f5c75-c4ed-3567-a850-52f21e30dc5c',
#  'd579122f-17aa-3706-bdcc-20dbba5c2ac9',
#  'df1ae6d6-a785-3a04-a0e1-52a0f4a7b980',
#  'race',
#  'makes',
#  '7bffe158-962f-3639-8b46-f0eb8e38d32f',
#  'capitol',
#  'hit',
#  '5f1b6278-9fda-3b4d-b062-03a0f27806eb',
#  '34e2bbd0-0051-3101-a300-8a68b5149e33',
#  '6f19c28a-0dd0-319a-a0d3-6dcce227c60b',
#  'behind',
#  'af8adb1c-cbf2-3407-a90c-ef1764b984b9',
#  'a26ff8a8-69a6-34a1-a8a7-96b477ee9dae',
#  'florida',
#  'Motor Sports',
#  'amid',
#  'well',
#  '305c82f0-8c92-30f4-ae1a-beeea50afbc6',
#  'together',
#  '7f85baf1-edc7-3b55-873e-150eed052b56',
#  'keep',
#  'california',
#  '08a3076a-f9fd-3c62-8293-463384c0effc',
#  'david',
#  'break',
#  'away',
#  '4b6e95d2-d081-399f-b1e4-d03634846720',
#  'future',
#  'director',
#  'late',
#  'media',
#  'play',
#  'head',
#  'players',
#  'office',
#  'actor',
#  'stories',
#  'comes',
#  'much',
#  'america',
#  'f8470427-210c-3667-8dfb-dced047d00d6',
#  '2010s',
#  'party',
#  'presidential',
#  'good',
#  'bidens',
#  'd5861cae-bcb0-33b6-81d8-29e64aa196c0',
#  '93afc399-fbc4-3f5a-8a7a-4b45c9365200',
#  'monday',
#  'Sci-Fi & Fantasy',
#  'goes',
#  'fight',
#  '0efb21e5-07f0-38e7-b4ce-60f0221e6d86',
#  'breaks',
#  'ba2d1380-b33d-377b-bf3f-54990ac1c7a2',
#  '--',
#  'taking',
#  'career',
#  'Mystery & Suspense',
#  'announced',
#  'return',
#  'teams',
#  'chief',
#  'support',
#  'lives',
#  'Pursuit',
#  'women',
#  'come',
#  '29727c90-108c-3fd5-872e-e8a607a8caf0',
#  'daughter',
#  'ahead',
#  'victory',
#  'music',
#  'decision',
#  'ee4dcdcd-e944-3b17-9e8d-1be16e547116',
#  'little',
#  'real',
#  'plans',
#  '1ff4154b-c611-307e-b080-018cf4a265ef',
#  'battle',
#  'sen',
#  'WWE',
#  '2037e17b-541a-3bd0-8e29-3a28d6e9ebdf',
#  'start',
#  'pop',
#  'plus',
#  '4c04cfd9-10c2-3f40-a468-3bf06d0d1466',
#  'vice',
#  'womens',
#  'lead',
#  'johnson',
#  'campaign',
#  'seth',
#  'd3417080-5a63-38fe-b7c9-eedceacab2ca',
#  'put',
#  '748df986-d56f-3fdd-a267-00c7e2db015e',
#  'market',
#  'kids',
#  '3b1a1cae-eb8a-3e34-bb72-e1c9808de03a',
#  'following',
#  '93dd0afb-5a48-3af5-a475-4dcb3b6597f7',
#  'end',
#  'dan',
#  'run',
#  'round',
#  'program',
#  '27d71341-1e3b-35e7-9145-a6f39b526010',
#  'favorite',
#  'b5920557-564f-3e1f-8ea8-141da3e7f70b',
#  '51f95be6-77cc-37e4-8640-8f9a06c9acb0',
#  'without',
#  'debate',
#  'df3473e2-1256-368d-861b-7bd51f478bfa',
#  'crisis',
#  'times',
#  'a8b32cd5-96a5-30fe-91e5-3d41d752dfa7',
#  'williams',
#  'testing',
#  'bell',
#  'four',
#  'sunday',
#  'scott',
#  'e949f054-e96c-3fd7-aea3-f7ab524d735d',
#  'singer',
#  'moments',
#  'got',
#  '487ee5dd-66a9-3d70-82ef-94aa4853f7ca',
#  'old',
#  'high',
#  'federal',
#  'relief',
#  'deal',
#  'b78da95b-56db-348b-9a63-bb7ef61b5f71',
#  'virus',
#  '7099178e-078e-3817-9645-ec4c4f7e88f5',
#  'give',
#  '2',
#  '6392ef89-910e-3e80-be83-5afa7710c008',
#  'medical',
#  'republican',
#  'rep',
#  'impact',
#  'due',
#  '8efd3b86-fccb-34b8-a1aa-b2b8c3814745',
#  '41a31817-4c7c-3887-ba3a-18e5388b6fee',
#  'global',
#  'use',
#  'shes',
#  'officials',
#  'street',
#  'compete',
#  'gives',
#  'upcoming',
#  'tuesday',
#  'senior',
#  'administration',
#  '1',
#  'continues',
#  '64fab910-3084-3edf-aca3-cf57fe51aa7d',
#  '4f9a7aa5-2d28-33aa-8097-61b7b68090af',
#  'move',
#  'dc7e37c0-64ac-384d-a2d5-5ac0c51ecece',
#  'wife',
#  'hospital',
#  'a23aabac-9acb-3972-b1d5-141e143a1a01',
#  'actress',
#  '7f067a57-916a-325d-98c5-f71e409f3218',
#  'court',
#  'right',
#  'early',
#  '82d98690-9848-3893-83d3-bf937a0b87d6',
#  'open',
#  '0caf099f-3e24-3280-b5ae-fd9404494ab2',
#  'football',
#  'change',
#  'role',
#  'place',
#  'older teens (ages 15+)',
#  'must',
#  'match',
#  'kevin',
#  'children',
#  'calls',
#  'Winter Sports',
#  'democratic',
#  'voice',
#  'college',
#  'call',
#  '745685fe-d30f-3452-96e6-2ce7b5b19ec5',
#  'super',
#  'every',
#  'd7762b50-c666-39ce-904c-07f0ea79a6d3',
#  'quarantine',
#  'mother',
#  'major',
#  'c6a01725-eee5-3724-b8e4-ab1fe52d3fda',
#  '10',
#  'tries',
#  'took',
#  "Children's/Family Entertainment",
#  '0504af2b-7dd1-3c97-9584-b33eb5708232',
#  'trial',
#  'crew',
#  'covid',
#  'championship',
#  'care',
#  'rumors',
#  'know',
#  'dog',
#  'trying',
#  'press',
#  'Lifestyle',
#  'rachel',
#  'angeles',
#  '9e5d932c-9a9a-3122-8592-bea0c229feba',
#  'est',
#  'members',
#  'along',
#  '78fc6e49-802d-3153-8304-5b7c4532833f',
#  'ever',
#  'continue',
#  'film',
#  'found',
#  'center',
#  'Home & How-To',
#  'Adventure',
#  'secretary',
#  'draft',
#  'd377b47f-7612-3bbb-a613-24d7912a0e05',
#  'general',
#  'entertainment',
#  'saying',
#  'meet',
#  'long',
#  'be66d458-dc20-381a-b44a-8b779971962e',
#  'justice',
#  'free',
#  'dont',
#  'despite',
#  'try',
#  'georgia',
#  'ad4afcae-0f61-34a7-a808-ab742f575712',
#  '5ef8c94d-8a88-3b7a-b947-7612f9004eb0',
#  '3c8c8e37-be62-355d-a6b4-7e594b58f789',
#  'event',
#  'b69af167-cb19-368c-8ba2-f5051f515530',
#  'cover',
#  'wants',
#  'vote',
#  'results',
#  'coach',
#  'father',
#  'cramer',
#  'workers',
#  'wwe',
#  'number',
#  'means',
#  'eisen',
#  'c5b61484-1a87-3a04-a310-5aa7ba0279a6',
#  '7d3afc3a-2587-3633-9586-14d4c20335d9',
#  'become',
#  'kate',
#  'baby',
#  'stop',
#  '4c413092-5898-3531-ade8-c803b2592963',
#  'park',
#  'order',
#  'Quest',
#  '0a8ee8e7-c45d-3f4d-9005-d07e1c138e47',
#  'c26ce94f-5daa-35cf-8536-4d5adf3c1522',
#  'west',
#  'case',
#  'patrick',
#  'friday',
#  'andy',
#  'stay',
#  'record',
#  'community',
#  'performs',
#  'nearly',
#  'anthony',
#  'harris',
#  'song',
#  'b8ad855d-3a54-38d0-b28e-96ad7b907d0f',
#  '4127af2f-cccd-35db-809e-157b0b9b69d0',
#  'recent',
#  'months',
#  'e9f9003e-66f6-33c0-b99a-6c0dd6257d95',
#  '7aa73909-1ece-3337-a983-557b14d398f6',
#  'others',
#  'jones',
#  'husband',
#  'held',
#  'd5850c8c-ebf9-361d-bad3-431752d42af8',
#  'never',
#  'food',
#  'book',
#  'games',
#  '38150b88-cf25-30ac-9327-417a6e61ad38',
#  'friend',
#  'close',
#  'adfc1b49-5be1-3ffc-b32a-b0a98f801ace',
#  'response',
#  'relationship',
#  'line',
#  'hoda',
#  'wednesday',
#  'events',
#  '418ee2f0-1b99-3f9c-9a8a-7ed4716bdcb1',
#  'mayor',
#  'south',
#  'andrew',
#  '895ed403-19bb-3f64-bb2f-a58b0031f3de',
#  'club',
#  'security',
#  'challenges',
#  'Horror',
#  'using',
#  'a434489a-1d47-3522-938f-182b615c316c',
#  '58f61bff-8284-326b-8391-43bea6e526c8',
#  'access',
#  'told',
#  'test',
#  'f525b406-7de7-30c7-a819-c6fec9935cd7',
#  'birthday',
#  'b442face-dddf-3119-a753-d04d5ca062a7',
#  'attorney',
#  'personal',
#  'Romance',
#  'think',
#  'positive',
#  'instagram',
#  'government',
#  'control',
#  'left',
#  'ser',
#  'parents',
#  'Cartoon & Animation',
#  'Animated',
#  '4a2924ed-8900-382b-8e41-4c8e7ed173f8',
#  'thursday',
#  'surprise',
#  'faf1d521-1e0a-311e-a89b-b541a200f247',
#  'coverage',
#  'inside',
#  'full',
#  'coming',
#  'christmas',
#  'president-elect',
#  'five',
#  'closing',
#  'Amusing',
#  'performance',
#  'title',
#  'small',
#  'congress',
#  'according',
#  'political',
#  'mark',
#  'joined',
#  '2dd492ad-e055-31be-b874-4cd0cf02e01e',
#  'floyd',
#  'want',
#  'eca8b79b-baf1-32c6-a598-c08a2bd62e97',
#  'road',
#  'cant',
#  '5225e94c-b9b8-3434-a7b6-6dea3743c8ae',
#  'looking',
#  'c69b593e-eb2c-3f64-ab34-8b7e06e47ce8',
#  'hollywood',
#  'bad',
#  '11358b5d-4f0b-3744-80a2-206a85224717',
#  'nueva',
#  'alex',
#  'experience',
#  'stephanie',
#  '5cb24e39-349c-301c-a869-ded27ec491bc',
#  'peacock',
#  'key',
#  'growing',
#  'different',
#  'd9318e35-1258-31a9-bfc8-a0646fb0c860',
#  'tras',
#  'bring',
#  'Suspenseful',
#  '2019',
#  'mens',
#  'e440ae9f-747b-3cf9-b6d3-74820ef630b4',
#  'local',
#  'finds',
#  'doesnt',
#  'pandemia',
#  'faces',
#  '358c106f-fc01-3666-a1d5-a705ecbf6fcc',
#  'potential',
#  'mad',
#  'voting',
#  'protests',
#  'fis',
#  '352652a6-7032-3e24-8860-a8bff5f2843e',
#  'moment',
#  'harry',
#  '630a8cc2-abb5-3aee-b607-e08af336d641',
#  '0d4e95f8-41db-3050-8b6c-15412f4249a7',
#  'eb467cc9-3359-3edf-b1ff-48562ac27505',
#  'ryan',
#  'really',
#  'murder',
#  'tv',
#  'Love',
#  'Rivalry',
#  '2000s',
#  'law',
#  'lost',
#  'better',
#  'officer',
#  'c396ec5f-b373-3536-84dc-13ae1fe14b38',
#  'a60dc60f-a9b9-3bba-b639-d7334e6063b6',
#  'republicans',
#  'died',
#  'shot',
#  'job',
#  'da',
#  'girl',
#  'explain',
#  'bcbb42ff-d966-3ce5-b346-1c334a8202e2',
#  'adems',
#  'learn',
#  'democrats',
#  '1d25e288-5f8a-363f-9241-e67e88223556',
#  'morgan',
#  'couple',
#  '3b793e2f-d833-3513-beba-ca68ca191e0f',
#  'returns',
#  'important',
#  '526dbd98-33dc-3080-8f4a-52ae4d1e574c',
#  'perform',
#  'brings',
#  'chef',
#  'cast',
#  '88e0c533-2b5a-3ce5-a347-52326598ef3f',
#  'tune',
#  'save',
#  'giving',
#  'dance',
#  '232a8cca-d154-3752-b78b-fd76826bfc4b',
#  'maddow',
#  'holiday',
#  'great',
#  'gov',
#  'trip',
#  'force',
#  'episode',
#  'town',
#  'holley',
#  '2020-21',
#  'speaks',
#  'a05dfa95-934f-37b3-958e-ac2d689d6fc7',
#  'bfbaa198-727c-3b0f-9f20-88d533d0c8ea',
#  'spread',
#  'international',
#  'university',
#  'stage',
#  'movie',
#  'd2978975-3c8f-3954-8473-fb8aa91376ba',
#  'amy',
#  '3',
#  'issues',
#  'pas',
#  'msnbcs',
#  'stadium',
#  'helps',
#  'champion',
#  '966868a2-3ba4-39b3-88f3-b7511b8d595d',
#  'turn',
#  'thinks',
#  'voters',
#  'virtual',
#  'turns',
#  'resources',
#  'robert',
#  'comments',
#  '9948dea9-a435-3855-8df9-c62466ef208c',
#  'ready',
#  'month',
#  'businesses',
#  '1dc24c35-6ba9-3108-84a6-6b54707d1be0',
#  'update',
#  'impeachment',
#  'taylor',
#  'students',
#  'tour',
#  'jenna',
#  'governor',
#  'answers',
#  'Engaging',
#  '935bab04-14a1-37db-81b9-8e626e481332',
#  '0e978474-2b2d-3bc1-a9be-d3b1a26ef690',
#  'theyre',
#  'rock',
#  'needs',
#  'stock',
#  'hall',
#  'six',
#  'claims',
#  'travel',
#  'Transformation',
#  'front',
#  'executive',
#  'cmo',
#  'visit',
#  'used',
#  'ski',
#  'secret',
#  'lee',
#  'Escape',
#  'service',
#  'Independent',
#  'conference',
#  'alexander',
#  'c6a8c231-48f6-33af-83fb-db0054937dd5',
#  'leads',
#  'ce854c70-a06f-3dad-bc24-c448436ea925',
#  'Fantasy',
#  'tim',
#  'car',
#  'spoke',
#  'brian',
#  'outbreak',
#  'hill',
#  '52654fc0-de55-3e0f-959b-cbad9283eb0f',
#  'summer',
#  'north',
#  'f624f3ce-38aa-3430-8f6f-eb7b9235cced',
#  'chicago',
#  'investigation',
#  'Science fiction',
#  'red',
#  'hard',
#  '492c5a4b-7035-3f89-a4c3-44e5e1273566',
#  'running',
#  'member',
#  'guest',
#  'forward',
#  'everyone',
#  'e02194dd-0529-348a-a1c6-49003f251629',
#  'department',
#  'shooting',
#  'aos',
#  'age',
#  'Intense',
#  '91063d75-83d1-39c1-abe4-2969f8e70710',
#  'nick',
#  'matt',
#  '20',
#  'shared',
#  'thats',
#  'supreme',
#  'several',
#  'playing',
#  'jackson',
#  'calling',
#  'nba',
#  'mom',
#  'leagues',
#  'finally',
#  'nuevo',
#  'd4efe2ff-48f3-359d-8d59-97800174867b',
#  '6',
#  '07066559-a91f-3c41-9c55-7d8d19ef4a1a',
#  'kamala',
#  'current',
#  'bowl',
#  'single',
#  'presidente',
#  'bab3597f-dd3e-3447-956e-27846c29cf9e',
#  'atlanta',
#  'name',
#  'might',
#  'honor',
#  'e8417d8f-1af9-3786-99ec-5da91d27493a',
#  'reporter',
#  'politics',
#  'da2aecaf-bd80-32f9-a263-a95d63aefd60',
#  'celebrate',
#  'be5705ad-41b3-3831-9df4-51c15dd4d115',
#  'rise',
#  'released',
#  'men',
#  'enough',
#  '08db5963-13f3-3ecb-b086-1f4ce1624ebb',
#  'went',
#  'challenge',
#  'came',
#  '2253fcf4-6d14-3b57-933e-a91de0703522',
#  'sanders',
#  'safe',
#  'miami',
#  'everything',
#  'child',
#  '3e85ee8a-9f2a-3944-a74e-bc13adfa88c8',
#  'safety',
#  'opens',
#  'economy',
#  'closer',
#  'believes',
#  'becomes',
#  'among',
#  'air',
#  'whats',
#  'iconic',
#  'fire',
#  'economic',
#  'vegas',
#  'expected',
#  'paul',
#  'jennifer',
#  'families',
#  ...]

# %%
# Get the data mapping for title : keywords
query = """
    WITH  titles AS (
        SELECT LOWER(program_title) AS program_title, k AS keywords
        FROM `res-nbcupea-dev-ds-sandbox-001.metadata_enhancement.synopsis_dylan_150tag_with_tokens_and_keywords`,
        UNNEST(keywords) k
    ),

    tok AS (
        SELECT ROW_NUMBER() OVER() row_number, tokens
        FROM `res-nbcupea-dev-ds-sandbox-001.metadata_enhancement.node2vec_token_edc_dev`
    )

    SELECT a.program_title, ARRAY_AGG(DISTINCT a.keywords) AS keywords, ARRAY_AGG(b.row_number) AS index,
        "merlin" AS dataset
    FROM titles a
    JOIN tok b
    ON a.keywords = b.tokens
    GROUP BY a.program_title
"""

df_map = client.query(query=query, location="US").to_dataframe()
df_map
# Out:
#                                       program_title  \
# 0                             tras el corazón verde
# 1                            bedard zamana kya jane
# 2                            unnaruge naan irundhal
# 3                           hitler's circle of evil
# 4       a special edition of the rachel maddow show
# ...                                             ...
# 359155                                   millonario
# 359156                             jane bleibt jane
# 359157                                     ucitelka
# 359158                                los recuerdos
# 359159                                nena, eres tú
#
#                                                  keywords  \
# 0       [Village, Jungle, Affair, Kidnapping, Smugglin...
# 1                                    [Crime drama, Crime]
# 2                               [Romantic comedy, Comedy]
# 3       [Politics & Government, Military & War, Docume...
# 4                           [News, Politics & Government]
# ...                                                   ...
# 359155                       [Comedy drama, Comedy-Drama]
# 359156                       [Comedy drama, Comedy-Drama]
# 359157                       [Comedy-Drama, Comedy drama]
# 359158                       [Comedy-Drama, Comedy drama]
# 359159                       [Comedy drama, Comedy-Drama]
#
#                                                     index dataset
# 0       [43231, 56288, 4121, 3064, 608, 87103, 4166, 8...  merlin
# 1                                             [2076, 277]  merlin
# 2                                              [20, 3177]  merlin
# 3                                       [3090, 6259, 231]  merlin
# 4                                               [3090, 1]  merlin
# ...                                                   ...     ...
# 359155                                       [1527, 2385]  merlin
# 359156                                       [1527, 2385]  merlin
# 359157                                       [1527, 2385]  merlin
# 359158                                       [1527, 2385]  merlin
# 359159                                       [1527, 2385]  merlin
#
# [359160 rows x 4 columns]

# %%
TITLES_QUERY_keywords = """
    CREATE TEMP FUNCTION strip_str_array(val ANY TYPE) AS ((
      SELECT ARRAY_AGG(DISTINCT TRIM(t))
      FROM UNNEST(val) t
      WHERE t != ""
    ));
    
    WITH titles_data AS (
        SELECT DISTINCT
            TitleDetails_title, 
            TitleType, 
            cid.content_ordinal_id,
            STRING_AGG(DISTINCT TitleTags, ',') AS TitleTags,
            STRING_AGG(DISTINCT TitleSubgenres, ',') AS TitleSubgenres
        FROM `res-nbcupea-dev-ds-sandbox-001.metadata_enhancement.ContentMetadataView` cmv
        LEFT JOIN `res-nbcupea-dev-ds-sandbox-001.recsystem.ContentOrdinalId` cid
            ON LOWER(cmv.TitleDetails_title) = LOWER(cid.program_title)
        WHERE 
            TitleDetails_longsynopsis IS NOT NULL
            AND cid.content_ordinal_id IS NOT NULL
        GROUP BY 
            TitleDetails_title, 
            TitleType,
            cid.content_ordinal_id
        ),
    
    keywords_table AS (SELECT TitleDetails_title AS program_title, 
        strip_str_array(SPLIT(COALESCE(NULLIF(ARRAY_TO_STRING([TitleTags,TitleSubgenres], ","), ""), "movie"), ",")) AS keywords,
    FROM titles_data),
    
    titles AS (
        SELECT LOWER(program_title) AS program_title, k AS keywords
        FROM keywords_table,
        UNNEST(keywords) k
    ),

    
    tok AS (
        SELECT ROW_NUMBER() OVER() row_number, tokens
        FROM `res-nbcupea-dev-ds-sandbox-001.metadata_enhancement.node2vec_token_edc_dev`
    )
    
    SELECT a.program_title, ARRAY_AGG(DISTINCT a.keywords) AS keywords, ARRAY_AGG(b.row_number) AS index,
        "cmv" AS dataset
    FROM titles a
    JOIN tok b
    ON a.keywords = b.tokens
    GROUP BY a.program_title
    
    
"""
df_map2 = client.query(query=TITLES_QUERY_keywords, location="US").to_dataframe()
df_map2
# Out:
#                                           program_title  \
# 0                                      reservation road
# 1                                        this christmas
# 2                                      poker after dark
# 3                                           rumble fish
# 4                                            dear santa
# ...                                                 ...
# 2260  carson kressley on "rupaul's drag race", emmy ...
# 2261                                          chia head
# 2262                                         wacky glue
# 2263                                        baby toupee
# 2264                                       reagan jeans
#
#                                                keywords  \
# 0     [Daughter, Thriller, Fight for justice, Invest...
# 1     [Amusing, Daughter, Love, Interracial relation...
# 2     [Sports, Poker, Sports non-event, Card Games, ...
# 3     [Girlfriend, 1980s, Pool hall, New York State,...
# 4     [Single woman, Kitchen, Heartwarming, Amusing,...
# ...                                                 ...
# 2260                                [Entertainment, TV]
# 2261                                [Entertainment, TV]
# 2262                                [Entertainment, TV]
# 2263                                [Entertainment, TV]
# 2264                                [Entertainment, TV]
#
#                                                   index dataset
# 0     [2266, 376, 74052, 2457, 76494, 2143, 1803, 44...     cmv
# 1     [734, 2266, 792, 95414, 1527, 374, 76454, 20, ...     cmv
# 2                           [3, 1513, 130, 1687, 2, 19]     cmv
# 3     [3997, 2045, 114825, 76458, 3442, 1298, 3504, ...     cmv
# 4     [87051, 19782, 2808, 734, 792, 151951, 102138,...     cmv
# ...                                                 ...     ...
# 2260                                             [7, 2]     cmv
# 2261                                             [7, 2]     cmv
# 2262                                             [7, 2]     cmv
# 2263                                             [7, 2]     cmv
# 2264                                             [7, 2]     cmv
#
# [2265 rows x 4 columns]

# %%
df = pd.concat([df_map, df_map2])
df = df.drop_duplicates(subset="program_title", keep="last").reset_index(drop=True)
df
# Out:
#                                             program_title  \
# 0                                   tras el corazón verde
# 1                                  bedard zamana kya jane
# 2                                  unnaruge naan irundhal
# 3                                 hitler's circle of evil
# 4             a special edition of the rachel maddow show
# ...                                                   ...
# 359541  carson kressley on "rupaul's drag race", emmy ...
# 359542                                          chia head
# 359543                                         wacky glue
# 359544                                        baby toupee
# 359545                                       reagan jeans
#
#                                                  keywords  \
# 0       [Village, Jungle, Affair, Kidnapping, Smugglin...
# 1                                    [Crime drama, Crime]
# 2                               [Romantic comedy, Comedy]
# 3       [Politics & Government, Military & War, Docume...
# 4                           [News, Politics & Government]
# ...                                                   ...
# 359541                                [Entertainment, TV]
# 359542                                [Entertainment, TV]
# 359543                                [Entertainment, TV]
# 359544                                [Entertainment, TV]
# 359545                                [Entertainment, TV]
#
#                                                     index dataset
# 0       [43231, 56288, 4121, 3064, 608, 87103, 4166, 8...  merlin
# 1                                             [2076, 277]  merlin
# 2                                              [20, 3177]  merlin
# 3                                       [3090, 6259, 231]  merlin
# 4                                               [3090, 1]  merlin
# ...                                                   ...     ...
# 359541                                             [7, 2]     cmv
# 359542                                             [7, 2]     cmv
# 359543                                             [7, 2]     cmv
# 359544                                             [7, 2]     cmv
# 359545                                             [7, 2]     cmv
#
# [359546 rows x 4 columns]

# %%
# Write titles to gcs bucket
fs = gcsfs.GCSFileSystem(project="res-nbcupea-dev-ds-sandbox-001")
content_titles = df["program_title"].to_list()
with fs.open("gs://edc-dev/content_titles_vocab", "w") as fid:
    fid.writelines("\n".join(content_titles))

# %%
# Make the embeddings
print("Loading model")
token_embed_url = "gs://edc-dev/kubeflowpipelines-default/tfx_pipeline_output/node2vec_sports_syn_0_1_1/Trainer/model/19130/serving_model_dir"
embed = tf.keras.models.load_model(token_embed_url).get_layer("Embedding")
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:1045: UserWarning: models.node2vec.node2vec is not loaded, but a Lambda layer uses it. It may cause errors.
#   , UserWarning)
# 100%|██████████| 360/360 [00:18<00:00, 19.66it/s]

# %%
batch_size = 1000
weights = []
# Run the inference
for i in tqdm(range(df.shape[0] // batch_size + 1)):
    start_index = i*batch_size
    end_index = min((i+1)*batch_size-1, df.shape[0])
    dataset = tf.ragged.constant(df.loc[start_index : end_index, "index"].values)
    y = embed(dataset)
    y = tf.math.reduce_mean(y, axis=1)
    weights.append(y)
weights = tf.concat(weights, axis=0)
# Out:
# 100%|██████████| 360/360 [00:16<00:00, 21.95it/s]

# %%
np.savez("content_titles_embed_weights.npz", weights=weights.numpy())

# %%
title_embed = tf.keras.layers.Embedding(input_dim=df.shape[0]+1, output_dim=32,  trainable=False, 
                                        weights=[np.vstack([weights.numpy().mean(axis=0, keepdims=True), weights.numpy()])], 
                                        input_length=1, name="Embedding")

class TitleEmbed(tf.keras.models.Model):
    def __init__(self):
        super(TitleEmbed, self).__init__()
        self.embedding = title_embed
    def call(self, inputs):
        return self.embedding(inputs)
    

my_title_embed = TitleEmbed()
my_title_embed.predict(np.array([0, 1, 2]))
tf.keras.models.save_model(my_title_embed, "gs://edc-dev/content_title_embeddings_model")
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f61cfa2c950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f61cfa2c950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO:tensorflow:Assets written to: gs://edc-dev/content_title_embeddings_model/assets
# INFO:tensorflow:Assets written to: gs://edc-dev/content_title_embeddings_model/assets

# %%
# Test to see if model works
loaded_embed_model = tf.keras.models.load_model("gs://edc-dev/content_title_embeddings_model")
loaded_embed_model(np.array([[1,3, 2, 5, 3]]).T)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# <tf.Tensor: shape=(5, 1, 32), dtype=float32, numpy=
# array([[[ 0.12985791,  0.2832828 ,  0.50509584, -0.5418582 ,
#           0.6364128 , -0.6614034 ,  0.9445423 , -0.18660134,
#          -0.11616606, -0.10965705,  0.41396153,  0.96076554,
#          -0.32583398, -0.31966394, -1.0485516 ,  0.37422   ,
#          -0.28770265,  0.6234262 , -0.37877914, -0.10321245,
#           0.24231797, -0.85194695, -0.6667286 ,  0.4043153 ,
#          -0.6070905 , -1.0451252 ,  0.34790373,  0.16936222,
#          -0.09113744, -0.76959187,  1.3112115 , -0.32723886]],
#
#        [[ 0.1724453 , -0.6333292 , -0.6595114 ,  0.32417938,
#          -1.2730378 ,  0.78159523,  0.11159571, -1.168035  ,
#           0.8676192 , -0.3781639 ,  0.47728372, -0.27029607,
#           0.15333055, -0.4790235 , -0.93399996, -0.21849036,
#          -1.1306108 ,  0.0467308 , -0.7266465 , -0.4294022 ,
#           0.5830752 ,  0.04852033, -0.45071438, -0.89420223,
#           0.7965966 , -0.44303605,  0.3146656 , -0.9004598 ,
#           0.09222154, -0.30251932,  1.6193714 , -0.86382717]],
#
#        [[-0.32916927,  0.2519995 ,  0.02463201,  1.117959  ,
#          -0.30467778, -1.3053746 ,  0.15034293,  1.0459994 ,
#           0.5621707 , -0.11459035, -0.8424166 ,  0.79762775,
#          -0.34043026,  1.1693814 , -0.47431216, -0.49556887,
#           0.05014077,  0.00929913, -0.49126247, -0.8592369 ,
#          -0.48495468, -0.1500876 ,  0.34918898, -0.21528494,
#          -0.35344005, -0.71355534, -0.411538  ,  1.00323   ,
#           0.8500975 , -0.9372686 ,  0.403913  ,  0.27833396]],
#
#        [[-0.01708043,  0.55127275,  0.3811996 , -0.34588414,
#           0.1501288 ,  0.21886735,  0.6398306 ,  0.26077595,
#           0.5799844 , -0.14371389,  0.15699881,  0.58713615,
#          -0.03334057,  0.2897052 , -0.8517582 ,  0.47873804,
#          -0.5379881 ,  0.31775612, -0.37672868, -0.4463112 ,
#           0.5113367 , -0.8861135 ,  0.03572146,  0.29833293,
#          -0.6430259 , -0.46234572,  0.4828494 , -0.22588092,
#           0.30719578, -0.09339515, -0.0132862 , -0.16175368]],
#
#        [[ 0.1724453 , -0.6333292 , -0.6595114 ,  0.32417938,
#          -1.2730378 ,  0.78159523,  0.11159571, -1.168035  ,
#           0.8676192 , -0.3781639 ,  0.47728372, -0.27029607,
#           0.15333055, -0.4790235 , -0.93399996, -0.21849036,
#          -1.1306108 ,  0.0467308 , -0.7266465 , -0.4294022 ,
#           0.5830752 ,  0.04852033, -0.45071438, -0.89420223,
#           0.7965966 , -0.44303605,  0.3146656 , -0.9004598 ,
#           0.09222154, -0.30251932,  1.6193714 , -0.86382717]]],
#       dtype=float32)>

# %%
loaded_embed_layer = loaded_embed_model.get_layer("Embedding")
loaded_embed_layer(np.array([[1,2,3,5]]).T)
# Out:
# <tf.Tensor: shape=(4, 1, 32), dtype=float32, numpy=
# array([[[ 0.12985791,  0.2832828 ,  0.50509584, -0.5418582 ,
#           0.6364128 , -0.6614034 ,  0.9445423 , -0.18660134,
#          -0.11616606, -0.10965705,  0.41396153,  0.96076554,
#          -0.32583398, -0.31966394, -1.0485516 ,  0.37422   ,
#          -0.28770265,  0.6234262 , -0.37877914, -0.10321245,
#           0.24231797, -0.85194695, -0.6667286 ,  0.4043153 ,
#          -0.6070905 , -1.0451252 ,  0.34790373,  0.16936222,
#          -0.09113744, -0.76959187,  1.3112115 , -0.32723886]],
#
#        [[-0.32916927,  0.2519995 ,  0.02463201,  1.117959  ,
#          -0.30467778, -1.3053746 ,  0.15034293,  1.0459994 ,
#           0.5621707 , -0.11459035, -0.8424166 ,  0.79762775,
#          -0.34043026,  1.1693814 , -0.47431216, -0.49556887,
#           0.05014077,  0.00929913, -0.49126247, -0.8592369 ,
#          -0.48495468, -0.1500876 ,  0.34918898, -0.21528494,
#          -0.35344005, -0.71355534, -0.411538  ,  1.00323   ,
#           0.8500975 , -0.9372686 ,  0.403913  ,  0.27833396]],
#
#        [[ 0.1724453 , -0.6333292 , -0.6595114 ,  0.32417938,
#          -1.2730378 ,  0.78159523,  0.11159571, -1.168035  ,
#           0.8676192 , -0.3781639 ,  0.47728372, -0.27029607,
#           0.15333055, -0.4790235 , -0.93399996, -0.21849036,
#          -1.1306108 ,  0.0467308 , -0.7266465 , -0.4294022 ,
#           0.5830752 ,  0.04852033, -0.45071438, -0.89420223,
#           0.7965966 , -0.44303605,  0.3146656 , -0.9004598 ,
#           0.09222154, -0.30251932,  1.6193714 , -0.86382717]],
#
#        [[-0.01708043,  0.55127275,  0.3811996 , -0.34588414,
#           0.1501288 ,  0.21886735,  0.6398306 ,  0.26077595,
#           0.5799844 , -0.14371389,  0.15699881,  0.58713615,
#          -0.03334057,  0.2897052 , -0.8517582 ,  0.47873804,
#          -0.5379881 ,  0.31775612, -0.37672868, -0.4463112 ,
#           0.5113367 , -0.8861135 ,  0.03572146,  0.29833293,
#          -0.6430259 , -0.46234572,  0.4828494 , -0.22588092,
#           0.30719578, -0.09339515, -0.0132862 , -0.16175368]]],
#       dtype=float32)>
