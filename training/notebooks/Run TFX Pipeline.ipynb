# %%
# %cd /home/jupyter/nbcu-metadata-enhancement/training/src
#%cd ~/Documents/Scripts/node2vec_pipeline
# Out:
# /home/jupyter/nbcu-metadata-enhancement/training/src

# %%
GOOGLE_CLOUD_PROJECT = "res-nbcupea-dev-ds-sandbox-001"
ENDPOINT='https://df6bc4688870067-dot-us-east1.pipelines.googleusercontent.com' # Enter your ENDPOINT here.
CUSTOM_TFX_IMAGE = CUSTOM_TFX_IMAGE='gcr.io/' + GOOGLE_CLOUD_PROJECT + '/tfx-pipeline'

# %%
# Set `PATH` to include user python binary directory and a directory containing `skaffold`, as well as `tfx`
PATH=%env PATH
# %env PATH={PATH}:/home/jupyter/.local/bin
#%env PATH={PATH}:~/Documents/Scripts/node2vec_pipeline/bin
# Out:
# env: PATH=/opt/conda/bin:/opt/conda/condabin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/jupyter/.local/bin:/home/jupyter/.local/bin:/home/jupyter/.local/bin:/home/jupyter/.local/bin:/home/jupyter/.local/bin

# %%
# Initial build: need to rebuilt 
# every time there is a version change
# !tfx pipeline create  \
--pipeline-path=/home/jupyter/nbcu-metadata-enhancement/training/src/kubeflow_dag_runner.py \
--endpoint={ENDPOINT} \
--build-target-image={CUSTOM_TFX_IMAGE}
# Out:
# 2021-04-16 23:09:48.231273: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-04-16 23:09:48.231329: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# CLI
# Creating pipeline
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# Reading build spec from build.yaml
# No local setup.py, copying the directory and configuring the PYTHONPATH.
# [Skaffold] Generating tags...
# [Skaffold]  - gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline -> gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline:latest
# [Skaffold] Checking cache...
# [Skaffold]  - gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline: Not found. Building
# [Skaffold] Starting build...
# [Skaffold] Building [gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline]...
# [Skaffold] Sending build context to Docker daemon  182.8kB
# [Skaffold] Step 1/4 : FROM tensorflow/tfx:0.26.0
# [Skaffold]  ---> 3230796f5988
# [Skaffold] Step 2/4 : WORKDIR /pipeline
# [Skaffold]  ---> Using cache
# [Skaffold]  ---> bf1010d19ddd
# [Skaffold] Step 3/4 : COPY ./ ./
# [Skaffold]  ---> 034dba83931c
# [Skaffold] Step 4/4 : ENV PYTHONPATH="/pipeline:${PYTHONPATH}"
# [Skaffold]  ---> Running in 071f2d6d8311
# [Skaffold] Removing intermediate container 071f2d6d8311
# [Skaffold]  ---> 74c1313c6e33
# [Skaffold] Successfully built 74c1313c6e33
# [Skaffold] Successfully tagged gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline:latest
# [Skaffold] The push refers to repository [gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline]
# [Skaffold] 56820f4f96d2: Preparing
# [Skaffold] f35309f9ae2b: Preparing
# [Skaffold] 23b988d0a368: Preparing
# [Skaffold] a0fdd9e79e13: Preparing
# [Skaffold] 7ed3e18de502: Preparing
# [Skaffold] fd335a0d8c48: Preparing
# [Skaffold] 7d985a940d09: Preparing
# [Skaffold] 4058ae03fa32: Preparing
# [Skaffold] e3437c61d457: Preparing
# [Skaffold] 84ff92691f90: Preparing
# [Skaffold] 54b00d861a7a: Preparing
# [Skaffold] c547358928ab: Preparing
# [Skaffold] 84ff92691f90: Preparing
# [Skaffold] c4e66be694ce: Preparing
# [Skaffold] 47cc65c6dd57: Preparing
# [Skaffold] 84ff92691f90: Waiting
# [Skaffold] 54b00d861a7a: Waiting
# [Skaffold] c547358928ab: Waiting
# [Skaffold] c4e66be694ce: Waiting
# [Skaffold] 47cc65c6dd57: Waiting
# [Skaffold] 7d985a940d09: Waiting
# [Skaffold] fd335a0d8c48: Waiting
# [Skaffold] 4058ae03fa32: Waiting
# [Skaffold] e3437c61d457: Waiting
# [Skaffold] 7ed3e18de502: Layer already exists
# [Skaffold] 23b988d0a368: Layer already exists
# [Skaffold] a0fdd9e79e13: Layer already exists
# [Skaffold] f35309f9ae2b: Layer already exists
# [Skaffold] fd335a0d8c48: Layer already exists
# [Skaffold] 7d985a940d09: Layer already exists
# [Skaffold] e3437c61d457: Layer already exists
# [Skaffold] 4058ae03fa32: Layer already exists
# [Skaffold] 84ff92691f90: Layer already exists
# [Skaffold] c547358928ab: Layer already exists
# [Skaffold] 54b00d861a7a: Layer already exists
# [Skaffold] c4e66be694ce: Layer already exists
# [Skaffold] 47cc65c6dd57: Layer already exists
# [Skaffold] 56820f4f96d2: Pushed
# [Skaffold] latest: digest: sha256:c31f42ca8f5d7acbe1bc8832dc8732850898947afd2e7d837433dbe5e21d75dd size: 3479
# [Skaffold] There is a new version (1.22.0) of Skaffold available. Download it from:
# [Skaffold]   https://github.com/GoogleContainerTools/skaffold/releases/tag/v1.22.0
# [Skaffold]
# New container image is built. Target image is available in the build spec file.
# 2021-04-16 23:10:04.700938: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-04-16 23:10:04.700997: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:absl:RuntimeParameter is only supported on Cloud-based DAG runner currently.
# WARNING:absl:`instance_name` is deprecated, please set the node id directly using `with_id()` or the `.id` setter.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Adding upstream dependencies for component BigQueryExampleGen
# INFO:absl:Adding upstream dependencies for component ImporterNode_import_user_schema
# INFO:absl:Adding upstream dependencies for component StatisticsGen
# INFO:absl:   ->  Component: ImporterNode_import_user_schema
# INFO:absl:   ->  Component: BigQueryExampleGen
# INFO:absl:Adding upstream dependencies for component Transform
# INFO:absl:   ->  Component: ImporterNode_import_user_schema
# INFO:absl:   ->  Component: BigQueryExampleGen
# INFO:absl:Adding upstream dependencies for component ExampleValidator
# INFO:absl:   ->  Component: ImporterNode_import_user_schema
# INFO:absl:   ->  Component: StatisticsGen
# INFO:absl:Adding upstream dependencies for component Trainer
# INFO:absl:   ->  Component: ImporterNode_import_user_schema
# INFO:absl:   ->  Component: Transform
# INFO:absl:Adding upstream dependencies for component EmbeddingEvaluator
# INFO:absl:   ->  Component: Trainer
# INFO:absl:Adding upstream dependencies for component Pusher
# INFO:absl:   ->  Component: Trainer
# Pipeline compiled successfully.
# Pipeline package path: /home/jupyter/nbcu-metadata-enhancement/training/src/metadata_dev_edc_base_0_0_1.tar.gz
# Pipeline "metadata_dev_edc_base_0_0_1" already exists.

# %%
PIPELINE_NAME = "metadata_dev_edc_base_0_0_1"
# !tfx run create --pipeline-name {PIPELINE_NAME} --endpoint={ENDPOINT}
# Out:
# 2021-04-16 22:09:14.973267: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-04-16 22:09:14.973315: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# CLI
# Creating a run for pipeline: metadata_dev_edc_base_0_0_1
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# Run created for pipeline: metadata_dev_edc_base_0_0_1
# +-----------------------------+--------------------------------------+----------+---------------------------+--------------------------------------------------------------------------------------------------------------------------+
# | pipeline_name               | run_id                               | status   | created_at                | link                                                                                                                     |
# +=============================+======================================+==========+===========================+==========================================================================================================================+
# | metadata_dev_edc_base_0_0_1 | b5292765-bb1a-4132-8c79-7e336835383b |          | 2021-04-16T22:09:19+00:00 | https://df6bc4688870067-dot-us-east1.pipelines.googleusercontent.com/#/runs/details/b5292765-bb1a-4132-8c79-7e336835383b |
# +-----------------------------+--------------------------------------+----------+---------------------------+--------------------------------------------------------------------------------------------------------------------------+

# %%
# Update
#!git pull origin meta-dev-edc
# !tfx pipeline update \
--pipeline-path=/home/jupyter/nbcu-metadata-enhancement/training/src/kubeflow_dag_runner.py \
--endpoint={ENDPOINT}

PIPELINE_NAME = "metadata_dev_edc_base_0_0_1"
# !tfx run create --pipeline-name {PIPELINE_NAME} --endpoint={ENDPOINT}
# Out:
# 2021-04-17 00:02:51.300789: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-04-17 00:02:51.300864: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# CLI
# Updating pipeline
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# Reading build spec from build.yaml
# [Skaffold] Generating tags...
# [Skaffold]  - gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline -> gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline:latest
# [Skaffold] Checking cache...
# [Skaffold]  - gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline: Not found. Building
# [Skaffold] Starting build...
# [Skaffold] Building [gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline]...
# [Skaffold] Sending build context to Docker daemon  295.9kB
# [Skaffold] Step 1/7 : FROM tensorflow/tfx:0.26.0
# [Skaffold]  ---> 3230796f5988
# [Skaffold] Step 2/7 : WORKDIR /pipeline
# [Skaffold]  ---> Using cache
# [Skaffold]  ---> bf1010d19ddd
# [Skaffold] Step 3/7 : COPY ./ ./
# [Skaffold]  ---> 3edff135600d
# [Skaffold] Step 4/7 : ENV PYTHONPATH="/pipeline:${PYTHONPATH}"
# [Skaffold]  ---> Running in f4a68f83c808
# [Skaffold] Removing intermediate container f4a68f83c808
# [Skaffold]  ---> 678be5b73c08
# [Skaffold] Step 5/7 : RUN pip install tensorflow_text
# [Skaffold]  ---> Running in 1bf2165d8705
# [Skaffold] Collecting tensorflow_text
# [Skaffold]   Downloading tensorflow_text-2.4.3-cp37-cp37m-manylinux1_x86_64.whl (3.4 MB)
# [Skaffold] Collecting tensorflow<2.5,>=2.4.0
# [Skaffold]   Downloading tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl (394.3 MB)
# [Skaffold] Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (0.9.0)
# [Skaffold] Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (3.3.0)
# [Skaffold] Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (1.19.5)
# [Skaffold] Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (1.12)
# [Skaffold] Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (0.36.2)
# [Skaffold] Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (2.10.0)
# [Skaffold] Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (3.14.0)
# [Skaffold] Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (1.1.0)
# [Skaffold] Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (0.2.0)
# [Skaffold] Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (2.4.0)
# [Skaffold] Collecting tensorflow-estimator<2.5.0,>=2.4.0
# [Skaffold]   Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# [Skaffold] Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (3.7.4.3)
# [Skaffold] Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (1.32.0)
# [Skaffold] Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (1.1.2)
# [Skaffold] Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (1.6.3)
# [Skaffold] Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (0.10.0)
# [Skaffold] Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (0.3.3)
# [Skaffold] Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (1.12.1)
# [Skaffold] Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.5,>=2.4.0->tensorflow_text) (1.15.0)
# [Skaffold] Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (3.3.3)
# [Skaffold] Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (1.0.1)
# [Skaffold] Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (1.7.0)
# [Skaffold] Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (49.2.0)
# [Skaffold] Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (1.24.0)
# [Skaffold] Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (0.4.2)
# [Skaffold] Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (2.25.1)
# [Skaffold] Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (3.3.0)
# [Skaffold] Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (4.2.0)
# [Skaffold] Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (4.6)
# [Skaffold] Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (0.2.8)
# [Skaffold] Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (1.3.0)
# [Skaffold] Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (1.26.2)
# [Skaffold] Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (2.10)
# [Skaffold] Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (4.0.0)
# [Skaffold] Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (2020.12.5)
# [Skaffold] Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (3.4.0)
# [Skaffold] Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (0.4.8)
# [Skaffold] Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow<2.5,>=2.4.0->tensorflow_text) (3.1.0)
# [Skaffold] Installing collected packages: tensorflow-estimator, tensorflow, tensorflow-text
# [Skaffold]   Attempting uninstall: tensorflow-estimator
# [Skaffold]     Found existing installation: tensorflow-estimator 2.3.0
# [Skaffold]     Uninstalling tensorflow-estimator-2.3.0:
# [Skaffold]       Successfully uninstalled tensorflow-estimator-2.3.0
# [Skaffold]   Attempting uninstall: tensorflow
# [Skaffold]     Found existing installation: tensorflow 2.3.2
# [Skaffold]     Uninstalling tensorflow-2.3.2:
# [Skaffold]       Successfully uninstalled tensorflow-2.3.2
# [Skaffold] ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
# [Skaffold]
# [Skaffold] We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
# [Skaffold]
# [Skaffold] tfx 0.26.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] tfx-bsl 0.26.1 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] tensorflow-transform 0.26.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] tensorflow-model-analysis 0.26.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] tensorflow-data-validation 0.26.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] Successfully installed tensorflow-2.4.1 tensorflow-estimator-2.4.0 tensorflow-text-2.4.3
# [Skaffold] WARNING: You are using pip version 20.2; however, version 21.0.1 is available.
# [Skaffold] You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# [Skaffold] Removing intermediate container 1bf2165d8705
# [Skaffold]  ---> c33a80779edc
# [Skaffold] Step 6/7 : RUN pip install pyarrow==3.0.0
# [Skaffold]  ---> Running in 8a1f89105784
# [Skaffold] Collecting pyarrow==3.0.0
# [Skaffold]   Downloading pyarrow-3.0.0-cp37-cp37m-manylinux2014_x86_64.whl (20.7 MB)
# [Skaffold] Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from pyarrow==3.0.0) (1.19.5)
# [Skaffold] Installing collected packages: pyarrow
# [Skaffold]   Attempting uninstall: pyarrow
# [Skaffold]     Found existing installation: pyarrow 0.17.1
# [Skaffold]     Uninstalling pyarrow-0.17.1:
# [Skaffold]       Successfully uninstalled pyarrow-0.17.1
# [Skaffold] ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
# [Skaffold]
# [Skaffold] We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
# [Skaffold]
# [Skaffold] tfx 0.26.0 requires pyarrow<0.18,>=0.17, but you'll have pyarrow 3.0.0 which is incompatible.
# [Skaffold] tfx 0.26.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] tfx-bsl 0.26.1 requires pyarrow<0.18,>=0.17, but you'll have pyarrow 3.0.0 which is incompatible.
# [Skaffold] tfx-bsl 0.26.1 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] tensorflow-transform 0.26.0 requires pyarrow<0.18,>=0.17, but you'll have pyarrow 3.0.0 which is incompatible.
# [Skaffold] tensorflow-transform 0.26.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] tensorflow-model-analysis 0.26.0 requires pyarrow<0.18,>=0.17, but you'll have pyarrow 3.0.0 which is incompatible.
# [Skaffold] tensorflow-model-analysis 0.26.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] tensorflow-data-validation 0.26.0 requires pyarrow<0.18,>=0.17, but you'll have pyarrow 3.0.0 which is incompatible.
# [Skaffold] tensorflow-data-validation 0.26.0 requires tensorflow!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15.2, but you'll have tensorflow 2.4.1 which is incompatible.
# [Skaffold] apache-beam 2.25.0 requires httplib2<0.18.0,>=0.8, but you'll have httplib2 0.18.1 which is incompatible.
# [Skaffold] apache-beam 2.25.0 requires pyarrow<0.18.0,>=0.15.1; python_version >= "3.0" or platform_system != "Windows", but you'll have pyarrow 3.0.0 which is incompatible.
# [Skaffold] Successfully installed pyarrow-3.0.0
# [Skaffold] WARNING: You are using pip version 20.2; however, version 21.0.1 is available.
# [Skaffold] You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# [Skaffold] Removing intermediate container 8a1f89105784
# [Skaffold]  ---> c0098fe2652b
# [Skaffold] Step 7/7 : RUN pip install google-cloud-storage==1.32.0
# [Skaffold]  ---> Running in 5fa58a94a7da
# [Skaffold] Collecting google-cloud-storage==1.32.0
# [Skaffold]   Downloading google_cloud_storage-1.32.0-py2.py3-none-any.whl (92 kB)
# [Skaffold] Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage==1.32.0) (1.24.0)
# [Skaffold] Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage==1.32.0) (2.25.1)
# [Skaffold] Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage==1.32.0) (1.5.0)
# [Skaffold] Requirement already satisfied: google-resumable-media<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage==1.32.0) (1.2.0)
# [Skaffold] Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.32.0) (4.6)
# [Skaffold] Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.32.0) (1.15.0)
# [Skaffold] Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.32.0) (49.2.0)
# [Skaffold] Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.32.0) (4.2.0)
# [Skaffold] Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.32.0) (0.2.8)
# [Skaffold] Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.32.0) (4.0.0)
# [Skaffold] Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.32.0) (1.26.2)
# [Skaffold] Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.32.0) (2020.12.5)
# [Skaffold] Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.32.0) (2.10)
# [Skaffold] Requirement already satisfied: google-api-core<2.0.0dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage==1.32.0) (1.24.1)
# [Skaffold] Requirement already satisfied: google-crc32c<2.0dev,>=1.0; python_version >= "3.5" in /usr/local/lib/python3.7/dist-packages (from google-resumable-media<2.0dev,>=1.0.0->google-cloud-storage==1.32.0) (1.1.0)
# [Skaffold] Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.32.0) (0.4.8)
# [Skaffold] Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage==1.32.0) (2020.5)
# [Skaffold] Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage==1.32.0) (3.14.0)
# [Skaffold] Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage==1.32.0) (1.52.0)
# [Skaffold] Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-crc32c<2.0dev,>=1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=1.0.0->google-cloud-storage==1.32.0) (1.14.4)
# [Skaffold] Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=1.0.0->google-cloud-storage==1.32.0) (2.20)
# [Skaffold] Installing collected packages: google-cloud-storage
# [Skaffold]   Attempting uninstall: google-cloud-storage
# [Skaffold]     Found existing installation: google-cloud-storage 1.35.0
# [Skaffold]     Uninstalling google-cloud-storage-1.35.0:
# [Skaffold]       Successfully uninstalled google-cloud-storage-1.35.0
# [Skaffold] Successfully installed google-cloud-storage-1.32.0
# [Skaffold] WARNING: You are using pip version 20.2; however, version 21.0.1 is available.
# [Skaffold] You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# [Skaffold] Removing intermediate container 5fa58a94a7da
# [Skaffold]  ---> fbf3680724a7
# [Skaffold] Successfully built fbf3680724a7
# [Skaffold] Successfully tagged gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline:latest
# [Skaffold] The push refers to repository [gcr.io/res-nbcupea-dev-ds-sandbox-001/tfx-pipeline]
# [Skaffold] aeb99f717be0: Preparing
# [Skaffold] 98a53f614a58: Preparing
# [Skaffold] 18a4b12ecbb6: Preparing
# [Skaffold] 1e3464e674a3: Preparing
# [Skaffold] f35309f9ae2b: Preparing
# [Skaffold] 23b988d0a368: Preparing
# [Skaffold] a0fdd9e79e13: Preparing
# [Skaffold] 7ed3e18de502: Preparing
# [Skaffold] fd335a0d8c48: Preparing
# [Skaffold] 7d985a940d09: Preparing
# [Skaffold] 4058ae03fa32: Preparing
# [Skaffold] e3437c61d457: Preparing
# [Skaffold] 84ff92691f90: Preparing
# [Skaffold] 54b00d861a7a: Preparing
# [Skaffold] c547358928ab: Preparing
# [Skaffold] 84ff92691f90: Preparing
# [Skaffold] c4e66be694ce: Preparing
# [Skaffold] 47cc65c6dd57: Preparing
# [Skaffold] 23b988d0a368: Waiting
# [Skaffold] a0fdd9e79e13: Waiting
# [Skaffold] 7ed3e18de502: Waiting
# [Skaffold] fd335a0d8c48: Waiting
# [Skaffold] 7d985a940d09: Waiting
# [Skaffold] 4058ae03fa32: Waiting
# [Skaffold] e3437c61d457: Waiting
# [Skaffold] 84ff92691f90: Waiting
# [Skaffold] 54b00d861a7a: Waiting
# [Skaffold] c547358928ab: Waiting
# [Skaffold] c4e66be694ce: Waiting
# [Skaffold] 47cc65c6dd57: Waiting
# [Skaffold] f35309f9ae2b: Layer already exists
# [Skaffold] 23b988d0a368: Layer already exists
# [Skaffold] a0fdd9e79e13: Layer already exists
# [Skaffold] 7ed3e18de502: Layer already exists
# [Skaffold] fd335a0d8c48: Layer already exists
# [Skaffold] 1e3464e674a3: Pushed
# [Skaffold] aeb99f717be0: Pushed
# [Skaffold] 7d985a940d09: Layer already exists
# [Skaffold] 4058ae03fa32: Layer already exists
# [Skaffold] e3437c61d457: Layer already exists
# [Skaffold] 84ff92691f90: Layer already exists
# [Skaffold] 54b00d861a7a: Layer already exists
# [Skaffold] c547358928ab: Layer already exists
# [Skaffold] 47cc65c6dd57: Layer already exists
# [Skaffold] c4e66be694ce: Layer already exists
# [Skaffold] 98a53f614a58: Pushed
# [Skaffold] 18a4b12ecbb6: Pushed
# [Skaffold] latest: digest: sha256:308fa2891f50c9bb24d0cb9c0a6d6f166e86b86e2bc9bac7ca59cee7afae5338 size: 4114
# [Skaffold] There is a new version (1.22.0) of Skaffold available. Download it from:
# [Skaffold]   https://github.com/GoogleContainerTools/skaffold/releases/tag/v1.22.0
# [Skaffold]
# New container image is built. Target image is available in the build spec file.
# 2021-04-17 00:05:48.390695: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-04-17 00:05:48.390763: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:absl:RuntimeParameter is only supported on Cloud-based DAG runner currently.
# WARNING:absl:`instance_name` is deprecated, please set the node id directly using `with_id()` or the `.id` setter.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Excluding no splits because exclude_splits is not set.
# INFO:absl:Adding upstream dependencies for component BigQueryExampleGen
# INFO:absl:Adding upstream dependencies for component ImporterNode_import_user_schema
# INFO:absl:Adding upstream dependencies for component StatisticsGen
# INFO:absl:   ->  Component: ImporterNode_import_user_schema
# INFO:absl:   ->  Component: BigQueryExampleGen
# INFO:absl:Adding upstream dependencies for component Transform
# INFO:absl:   ->  Component: ImporterNode_import_user_schema
# INFO:absl:   ->  Component: BigQueryExampleGen
# INFO:absl:Adding upstream dependencies for component ExampleValidator
# INFO:absl:   ->  Component: ImporterNode_import_user_schema
# INFO:absl:   ->  Component: StatisticsGen
# INFO:absl:Adding upstream dependencies for component Trainer
# INFO:absl:   ->  Component: ImporterNode_import_user_schema
# INFO:absl:   ->  Component: Transform
# INFO:absl:Adding upstream dependencies for component EmbeddingEvaluator
# INFO:absl:   ->  Component: Trainer
# INFO:absl:Adding upstream dependencies for component Pusher
# INFO:absl:   ->  Component: Trainer
# Pipeline compiled successfully.
# Pipeline package path: /home/jupyter/nbcu-metadata-enhancement/training/src/metadata_dev_edc_base_0_0_1.tar.gz
# {'code_source_url': None,
#  'created_at': datetime.datetime(2021, 4, 17, 0, 5, 53, tzinfo=tzlocal()),
#  'id': 'ff45d840-b699-4928-9deb-dc6009cc01ca',
#  'name': 'metadata_dev_edc_base_0_0_1_20210417000552',
#  'package_url': None,
#  'parameters': [{'name': 'pipeline-root',
#                  'value': 'gs://metadata-bucket-base/tfx-metadata-dev-pipeline-output/metadata_dev_edc_base_0_0_1'}],
#  'resource_references': [{'key': {'id': '9f38339c-bfb3-482d-81f4-a8272fed27c0',
#                                   'type': 'PIPELINE'},
#                           'name': None,
#                           'relationship': 'OWNER'}]}
# Please access the pipeline detail page at https://df6bc4688870067-dot-us-east1.pipelines.googleusercontent.com/#/pipelines/details/9f38339c-bfb3-482d-81f4-a8272fed27c0
# Pipeline "metadata_dev_edc_base_0_0_1" updated successfully.
# 2021-04-17 00:05:54.157476: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-04-17 00:05:54.157527: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# CLI
# Creating a run for pipeline: metadata_dev_edc_base_0_0_1
# Detected Kubeflow.
# Use --engine flag if you intend to use a different orchestrator.
# Run created for pipeline: metadata_dev_edc_base_0_0_1
# +-----------------------------+--------------------------------------+----------+---------------------------+--------------------------------------------------------------------------------------------------------------------------+
# | pipeline_name               | run_id                               | status   | created_at                | link                                                                                                                     |
# +=============================+======================================+==========+===========================+==========================================================================================================================+
# | metadata_dev_edc_base_0_0_1 | 1455d555-1207-40c0-bc8d-1a921c714203 |          | 2021-04-17T00:05:58+00:00 | https://df6bc4688870067-dot-us-east1.pipelines.googleusercontent.com/#/runs/details/1455d555-1207-40c0-bc8d-1a921c714203 |
# +-----------------------------+--------------------------------------+----------+---------------------------+--------------------------------------------------------------------------------------------------------------------------+
